# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
mayDf = pd.read_csv("mayDf.csv")
mayDf
# Out:
#          Unnamed: 0 UDFSTRING15  OPH3                   SHRTNAME  \
# 0                 0     DIGITAL   KAR        CHIKMAGALUR-MG ROAD
# 1                 1     DIGITAL  UP11                   BAREILLY
# 2                 2     DIGITAL   MP1         JABALPUR-DAMOHNAKA
# 3                 3     DIGITAL    UK     DEHRADUN-HARIDWAR ROAD
# 4                 4     DIGITAL    UK     DEHRADUN-HARIDWAR ROAD
# ...             ...         ...   ...                        ...
# 6277534      201095     DIGITAL  JHK2                    DEOGHAR
# 6277535      201096     DIGITAL  JHK2                     PHUSRO
# 6277536      201097     DIGITAL  JHK1  JAMSHEDPUR-SAKCHI AMBAGAN
# 6277537      201098     DIGITAL  UP13            CHINHAT-LUCKNOW
# 6277538      201099     DIGITAL   UP6              SHAHAJAHANPUR
#
#          ADM_SITE_CODE    BILLDATE LEV1GRPNAME       LEV2GRPNAME  \
# 0            102485.00  2024-05-01         Men  Mens Sports Wear
# 1            100677.00  2024-05-01         Men        Mens Upper
# 2            101315.00  2024-05-01         Men        Mens Upper
# 3            101757.00  2024-05-01         Men        Mens Upper
# 4            101757.00  2024-05-01         Men        Mens Upper
# ...                ...         ...         ...               ...
# 6277534      100366.00  2024-05-31       Girls      Girls Junior
# 6277535      101046.00  2024-05-31       Girls      Girls Junior
# 6277536      101145.00  2024-05-31       Girls      Girls Junior
# 6277537      101161.00  2024-05-31        Boys       Boys Senior
# 6277538          47.00  2024-05-31        Boys       Boys Senior
#
#                GRPNAME  ARTICLECODE  ...     UDFSTRING07 UDFSTRING08  \
# 0             Sando[M]        25.00  ...             NaN         NaN
# 1        T-Shirt FS[M]      2650.00  ...        ALL OVER     REGULAR
# 2        T-Shirt FS[M]      2650.00  ...        ALL OVER     REGULAR
# 3        T-Shirt FS[M]      2650.00  ...        ALL OVER     REGULAR
# 4        T-Shirt FS[M]      2650.00  ...        ALL OVER     REGULAR
# ...                ...          ...  ...             ...         ...
# 6277534    T-Shirt[GJ]     58248.00  ...           FRONT     REGULAR
# 6277535    T-Shirt[GJ]     58248.00  ...           FRONT     REGULAR
# 6277536    T-Shirt[GJ]     58248.00  ...           FRONT     REGULAR
# 6277537      Shorts[B]     17145.00  ...  ALL OVER PRINT  ABOVE KNEE
# 6277538      Shorts[B]     17145.00  ...  ALL OVER PRINT  ABOVE KNEE
#
#         UDFSTRING09 UDFSTRING10 GROSSAMT MRPAMT NETAMT  QTY DISCOUNTAMT  \
# 0               NaN         NaN   249.00 249.00 249.00 1.00        0.00
# 1               NaN         NaN     0.01 249.00   0.01 1.00        0.00
# 2               NaN         NaN     0.01 249.00   0.01 1.00        0.00
# 3               NaN         NaN     0.01 249.00   0.01 1.00        0.00
# 4               NaN         NaN     0.01 249.00   0.01 1.00        0.00
# ...             ...         ...      ...    ...    ...  ...         ...
# 6277534         NaN         NaN   126.75 169.00 126.75 1.00        0.00
# 6277535         NaN         NaN   126.75 169.00 126.75 1.00        0.00
# 6277536         NaN         NaN   126.75 169.00 126.75 1.00        0.00
# 6277537         NaN         NaN   199.00 199.00 199.00 1.00        0.00
# 6277538         NaN         NaN   199.00 199.00 199.00 1.00        0.00
#
#         PROMOAMT
# 0           0.00
# 1         248.99
# 2         248.99
# 3         248.99
# 4         248.99
# ...          ...
# 6277534    42.25
# 6277535    42.25
# 6277536    42.25
# 6277537     0.00
# 6277538     0.00
#
# [6277539 rows x 34 columns]

# %%
df = mayDf[['LEV1GRPNAME','BILLDATE','GROSSAMT', 'MRPAMT', 'NETAMT', 'QTY', 'DISCOUNTAMT', 'PROMOAMT']]
df
# Out:
#         LEV1GRPNAME    BILLDATE  GROSSAMT  MRPAMT  NETAMT  QTY  DISCOUNTAMT  \
# 0               Men  2024-05-01    249.00  249.00  249.00 1.00         0.00
# 1               Men  2024-05-01      0.01  249.00    0.01 1.00         0.00
# 2               Men  2024-05-01      0.01  249.00    0.01 1.00         0.00
# 3               Men  2024-05-01      0.01  249.00    0.01 1.00         0.00
# 4               Men  2024-05-01      0.01  249.00    0.01 1.00         0.00
# ...             ...         ...       ...     ...     ...  ...          ...
# 6277534       Girls  2024-05-31    126.75  169.00  126.75 1.00         0.00
# 6277535       Girls  2024-05-31    126.75  169.00  126.75 1.00         0.00
# 6277536       Girls  2024-05-31    126.75  169.00  126.75 1.00         0.00
# 6277537        Boys  2024-05-31    199.00  199.00  199.00 1.00         0.00
# 6277538        Boys  2024-05-31    199.00  199.00  199.00 1.00         0.00
#
#          PROMOAMT
# 0            0.00
# 1          248.99
# 2          248.99
# 3          248.99
# 4          248.99
# ...           ...
# 6277534     42.25
# 6277535     42.25
# 6277536     42.25
# 6277537      0.00
# 6277538      0.00
#
# [6277539 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6277539 entries, 0 to 6277538
# Data columns (total 8 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   LEV1GRPNAME  object
#  1   BILLDATE     object
#  2   GROSSAMT     float64
#  3   MRPAMT       float64
#  4   NETAMT       float64
#  5   QTY          float64
#  6   DISCOUNTAMT  float64
#  7   PROMOAMT     float64
# dtypes: float64(6), object(2)
# memory usage: 383.2+ MB

# %%
df["BILLDATE"] = pd.to_datetime(df["BILLDATE"])
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\811933721.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["BILLDATE"] = pd.to_datetime(df["BILLDATE"])

# %%
df[['GROSSAMT', 'MRPAMT', 'NETAMT', 'QTY', 'DISCOUNTAMT', 'PROMOAMT']].isnull().sum()
# Out:
# GROSSAMT       0
# MRPAMT         0
# NETAMT         0
# QTY            0
# DISCOUNTAMT    0
# PROMOAMT       0
# dtype: int64

# %%
df[(df['GROSSAMT']<0) | (df['MRPAMT']<0) | (df['NETAMT']<0) | (df['QTY']<0) | (df['DISCOUNTAMT']<0) | (df['PROMOAMT']<0)]
# Out:
#            LEV1GRPNAME   BILLDATE  GROSSAMT  MRPAMT  NETAMT   QTY  \
# 49                 Men 2024-05-01   -299.00 -299.00 -299.00 -1.00
# 70                 Men 2024-05-01   -449.00 -449.00 -449.00 -1.00
# 105                Men 2024-05-01   -186.75 -249.00 -186.75 -1.00
# 177              Girls 2024-05-01   -499.00 -499.00 -499.00 -1.00
# 182              Girls 2024-05-01   -499.00 -499.00 -499.00 -1.00
# ...                ...        ...       ...     ...     ...   ...
# 6277457           Boys 2024-05-31   -149.25 -199.00 -149.25 -1.00
# 6277491   Women Ethnic 2024-05-31   -449.25 -599.00 -449.25 -1.00
# 6277502   Women Ethnic 2024-05-31     -0.01 -599.00   -0.01 -1.00
# 6277522          Girls 2024-05-31   -224.25 -299.00 -224.25 -1.00
# 6277532  Women Western 2024-05-31   -499.00 -499.00 -499.00 -1.00
#
#          DISCOUNTAMT  PROMOAMT
# 49              0.00      0.00
# 70              0.00      0.00
# 105             0.00    -62.25
# 177             0.00      0.00
# 182             0.00      0.00
# ...              ...       ...
# 6277457         0.00    -49.75
# 6277491         0.00   -149.75
# 6277502         0.00   -598.99
# 6277522         0.00    -74.75
# 6277532         0.00      0.00
#
# [169784 rows x 8 columns]

# %%
df["LEV1GRPNAME"].unique()
# Out:
# array(['Men', 'Boys', 'Women Western', 'Girls', 'Infant', 'Women Ethnic'],
#       dtype=object)

# %%
groupL1nDateDf = df.groupby(
    by=["LEV1GRPNAME", "BILLDATE"]
).agg({
    "GROSSAMT": "sum",
    "MRPAMT": "sum",
    "NETAMT": "sum",
    "QTY": "sum",
    "DISCOUNTAMT": "sum",
    "PROMOAMT": "sum"
}).reset_index()

# %%
groupL1nDateDf[['GROSSAMT', 'MRPAMT', 'NETAMT']] = groupL1nDateDf[['GROSSAMT', 'MRPAMT', 'NETAMT']]/10000000

# %%
groupL1nDateDf[["QTY"]] = groupL1nDateDf[["QTY"]]/10000 
groupL1nDateDf[["DISCOUNTAMT", "PROMOAMT"]] = groupL1nDateDf[["DISCOUNTAMT", "PROMOAMT"]]/100000

# %%
groupL1nDateDf[groupL1nDateDf['LEV1GRPNAME'] == 'Men']
# Out:
#     LEV1GRPNAME   BILLDATE  GROSSAMT  MRPAMT  NETAMT  QTY  DISCOUNTAMT  \
# 93          Men 2024-05-01      2.66    3.02    2.65 6.71         0.91
# 94          Men 2024-05-02      2.21    2.47    2.20 5.74         0.85
# 95          Men 2024-05-03      2.28    2.54    2.27 5.89         0.82
# 96          Men 2024-05-04      2.75    3.08    2.74 6.94         1.04
# 97          Men 2024-05-05      3.58    4.05    3.57 9.08         1.33
# 98          Men 2024-05-06      2.18    2.44    2.17 5.71         0.79
# 99          Men 2024-05-07      2.16    2.42    2.15 5.59         0.82
# 100         Men 2024-05-08      2.42    2.72    2.41 6.19         1.01
# 101         Men 2024-05-09      2.36    2.65    2.35 5.87         0.99
# 102         Men 2024-05-10      2.51    2.82    2.50 6.32         1.07
# 103         Men 2024-05-11      2.95    3.33    2.94 7.29         1.22
# 104         Men 2024-05-12      3.65    4.13    3.64 9.19         1.28
# 105         Men 2024-05-13      2.06    2.32    2.06 5.39         0.81
# 106         Men 2024-05-14      2.29    2.56    2.28 6.03         1.02
# 107         Men 2024-05-15      2.26    2.54    2.25 5.91         1.01
# 108         Men 2024-05-16      2.33    2.62    2.32 6.11         0.89
# 109         Men 2024-05-17      2.48    2.76    2.47 6.47         0.90
# 110         Men 2024-05-18      2.77    3.11    2.76 7.13         1.10
# 111         Men 2024-05-19      3.63    4.09    3.62 9.41         1.37
# 112         Men 2024-05-20      2.26    2.52    2.25 5.99         0.84
# 113         Men 2024-05-21      2.37    2.64    2.36 6.30         1.01
groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Men')]
mw1m = mayWeek1men.sum()[1:]
mw1m["week"] = "May Week 1 (5D)"
mw1m["LEV1GRPNAME"] = "Men"
mw1m = pd.DataFrame(mw1m).T

start_date = '2024-05-06'
end_date = '2024-05-12'
mayWeek2men = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Men')]
mw2m = mayWeek2men.sum()[1:]
mw2m["week"] = "May Week 2 (7D)"
mw2m["LEV1GRPNAME"] = "Men"
mw2m = pd.DataFrame(mw2m).T

start_date = '2024-05-13'
end_date = '2024-05-19'
mayWeek3men = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Men')]
mw3m = mayWeek3men.sum()[1:]
mw3m["week"] = "May Week 3 (7D)"
mw3m["LEV1GRPNAME"] = "Men"
mw3m = pd.DataFrame(mw3m).T

start_date = '2024-05-20'
end_date = '2024-05-26'
mayWeek4men = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Men')]
mw4m = mayWeek4men.sum()[1:]
mw4m["week"] = "May Week 4 (7D)"
mw4m["LEV1GRPNAME"] = "Men"
mw4m = pd.DataFrame(mw4m).T

start_date = '2024-05-27'
end_date = '2024-05-31'
mayWeek5men = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Men')]
mw5m = mayWeek1men.sum()[1:]
mw5m["week"] = "May Week 5 (5D)"
mw5m["LEV1GRPNAME"] = "Men"
mw5m = pd.DataFrame(mw5m).T

mayWbwWL1Dfm = pd.concat([mw1m,mw2m,mw3m,mw4m,mw5m])
mayWbwWL1Dfm
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\589299779.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw1m = mayWeek1men.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\589299779.py:12: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw2m = mayWeek2men.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\589299779.py:20: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw3m = mayWeek3men.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\589299779.py:28: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw4m = mayWeek4men.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\589299779.py:36: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw5m = mayWeek1men.sum()[1:]
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT             week  \
# 0    13.49  15.16  13.44 34.36        4.95   167.16  May Week 1 (5D)
# 0    18.21  20.51  18.14 46.17        7.18   229.61  May Week 2 (7D)
# 0    17.81  19.99  17.74 46.44        7.10   218.18  May Week 3 (7D)
# 0    18.13  20.23  18.06 47.41        7.17   210.50  May Week 4 (7D)
# 0    13.49  15.16  13.44 34.36        4.95   167.16  May Week 5 (5D)
#
#   LEV1GRPNAME
# 0         Men
# 0         Men
# 0         Men
# 0         Men
# 0         Men

# %%
mayL1Dfm = mayWbwWL1Dfm.sum()[:-2]
mayL1Dfm["LEV1GRPNAME"] = "Men"
mayL1Dfm = pd.DataFrame(mayL1Dfm).T
mayL1Dfm
# Out:
#   GROSSAMT MRPAMT NETAMT    QTY DISCOUNTAMT PROMOAMT LEV1GRPNAME
# 0    81.13  91.05  80.81 208.73       31.36   992.61         Men

# %%
start_date = '2024-05-01'
end_date = '2024-05-05'
mayWeek1boys = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Boys')]
mw1b = mayWeek1boys.sum()[1:]
mw1b["week"] = "May Week 1 (5D)"
mw1b["LEV1GRPNAME"] = "Boys"
mw1b = pd.DataFrame(mw1b).T

start_date = '2024-05-06'
end_date = '2024-05-12'
mayWeek2boys = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Boys')]
mw2b = mayWeek2boys.sum()[1:]
mw2b["week"] = "May Week 2 (7D)"
mw2b["LEV1GRPNAME"] = "Boys"
mw2b = pd.DataFrame(mw2b).T

start_date = '2024-05-13'
end_date = '2024-05-19'
mayWeek3boys = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Boys')]
mw3b = mayWeek3boys.sum()[1:]
mw3b["week"] = "May Week 3 (7D)"
mw3b["LEV1GRPNAME"] = "Boys"
mw3b = pd.DataFrame(mw3b).T

start_date = '2024-05-20'
end_date = '2024-05-26'
mayWeek4boys = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Boys')]
mw4b = mayWeek4boys.sum()[1:]
mw4b["week"] = "May Week 4 (7D)"
mw4b["LEV1GRPNAME"] = "Boys"
mw4b = pd.DataFrame(mw4b).T

start_date = '2024-05-27'
end_date = '2024-05-31'
mayWeek5boys = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Boys')]
mw5b = mayWeek1boys.sum()[1:]
mw5b["week"] = "May Week 5 (5D)"
mw5b["LEV1GRPNAME"] = "Boys"
mw5b = pd.DataFrame(mw5b).T

mayWbwWL1Dfb = pd.concat([mw1b,mw2b,mw3b,mw4b,mw5b])
mayWbwWL1Dfb
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\9618413.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw1b = mayWeek1boys.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\9618413.py:12: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw2b = mayWeek2boys.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\9618413.py:20: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw3b = mayWeek3boys.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\9618413.py:28: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw4b = mayWeek4boys.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\9618413.py:36: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw5b = mayWeek1boys.sum()[1:]
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT             week  \
# 0     3.79   4.36   3.78 14.77        1.21    56.50  May Week 1 (5D)
# 0     5.28   6.07   5.26 20.43        1.71    79.24  May Week 2 (7D)
# 0     5.61   6.45   5.59 21.85        1.99    84.09  May Week 3 (7D)
# 0     6.13   7.05   6.11 23.85        2.20    92.41  May Week 4 (7D)
# 0     3.79   4.36   3.78 14.77        1.21    56.50  May Week 5 (5D)
#
#   LEV1GRPNAME
# 0        Boys
# 0        Boys
# 0        Boys
# 0        Boys
# 0        Boys

# %%
mayL1Dfb = mayWbwWL1Dfb.sum()[:-2]
mayL1Dfb["LEV1GRPNAME"] = "Boys"
mayL1Dfb = pd.DataFrame(mayL1Dfb).T
mayL1Dfb
# Out:
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT LEV1GRPNAME
# 0    24.59  28.28  24.51 95.68        8.32   368.74        Boys

# %%
start_date = '2024-05-01'
end_date = '2024-05-05'
mayWeek1ww = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Women Western')]
mw1ww = mayWeek1ww.sum()[1:]
mw1ww["week"] = "May Week 1 (5D)"
mw1ww["LEV1GRPNAME"] = "Wester Women"
mw1ww = pd.DataFrame(mw1ww).T

start_date = '2024-05-06'
end_date = '2024-05-12'
mayWeek2ww = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Women Western')]
mw2ww = mayWeek2ww.sum()[1:]
mw2ww["week"] = "May Week 2 (7D)"
mw2ww["LEV1GRPNAME"] = "Wester Women"
mw2ww = pd.DataFrame(mw2ww).T

start_date = '2024-05-13'
end_date = '2024-05-19'
mayWeek3ww = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Women Western')]
mw3ww = mayWeek3ww.sum()[1:]
mw3ww["week"] = "May Week 3 (7D)"
mw3ww["LEV1GRPNAME"] = "Wester Women"
mw3ww = pd.DataFrame(mw3ww).T

start_date = '2024-05-20'
end_date = '2024-05-26'
mayWeek4ww = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Women Western')]
mw4ww = mayWeek4ww.sum()[1:]
mw4ww["week"] = "May Week 4 (7D)"
mw4ww["LEV1GRPNAME"] = "Wester Women"
mw4ww = pd.DataFrame(mw4ww).T

start_date = '2024-05-27'
end_date = '2024-05-31'
mayWeek5ww = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Women Western')]
mw5ww = mayWeek5ww.sum()[1:]
mw5ww["week"] = "May Week 5 (5D)"
mw5ww["LEV1GRPNAME"] = "Wester Women"
mw5ww = pd.DataFrame(mw5ww).T

mayWbwWL1Dfww = pd.concat([mw1ww,mw2ww,mw3ww,mw4ww,mw5ww])
mayWbwWL1Dfww
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\2244521723.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw1ww = mayWeek1ww.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\2244521723.py:12: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw2ww = mayWeek2ww.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\2244521723.py:20: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw3ww = mayWeek3ww.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\2244521723.py:28: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw4ww = mayWeek4ww.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\2244521723.py:36: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw5ww = mayWeek5ww.sum()[1:]
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT             week  \
# 0     5.16   5.68   5.14 17.14        1.46    52.20  May Week 1 (5D)
# 0     6.97   7.65   6.95 23.01        2.05    68.33  May Week 2 (7D)
# 0     7.29   7.99   7.26 24.26        2.31    70.00  May Week 3 (7D)
# 0     7.75   8.53   7.72 25.91        2.36    77.80  May Week 4 (7D)
# 0     4.93   5.45   4.91 16.81        1.50    51.84  May Week 5 (5D)
#
#     LEV1GRPNAME
# 0  Wester Women
# 0  Wester Women
# 0  Wester Women
# 0  Wester Women
# 0  Wester Women

# %%
mayL1Dfww = mayWbwWL1Dfww.sum()[:-2]
mayL1Dfww["LEV1GRPNAME"] = "Wester Women"
mayL1Dfww = pd.DataFrame(mayL1Dfww).T
mayL1Dfww
# Out:
#   GROSSAMT MRPAMT NETAMT    QTY DISCOUNTAMT PROMOAMT   LEV1GRPNAME
# 0    32.09  35.29  31.99 107.13        9.67   320.16  Wester Women

# %%
start_date = '2024-05-01'
end_date = '2024-05-05'
mayWeek1girls = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Girls')]
mw1girls = mayWeek1girls.sum()[1:]
mw1girls["week"] = "May Week 1 (5D)"
mw1girls["LEV1GRPNAME"] = "Girls"
mw1girls = pd.DataFrame(mw1girls).T

start_date = '2024-05-06'
end_date = '2024-05-12'
mayWeek2girls = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Girls')]
mw2girls = mayWeek2girls.sum()[1:]
mw2girls["week"] = "May Week 2 (7D)"
mw2girls["LEV1GRPNAME"] = "Girls"
mw2girls = pd.DataFrame(mw2girls).T

start_date = '2024-05-13'
end_date = '2024-05-19'
mayWeek3girls = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Girls')]
mw3girls = mayWeek3girls.sum()[1:]
mw3girls["week"] = "May Week 3 (7D)"
mw3girls["LEV1GRPNAME"] = "Girls"
mw3girls = pd.DataFrame(mw3girls).T

start_date = '2024-05-20'
end_date = '2024-05-26'
mayWeek4girls = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Girls')]
mw4girls = mayWeek4girls.sum()[1:]
mw4girls["week"] = "May Week 4 (7D)"
mw4girls["LEV1GRPNAME"] = "Girls"
mw4girls = pd.DataFrame(mw4girls).T

start_date = '2024-05-27'
end_date = '2024-05-31'
mayWeek5girls = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Girls')]
mw5girls = mayWeek5girls.sum()[1:]
mw5girls["week"] = "May Week 5 (5D)"
mw5girls["LEV1GRPNAME"] = "Girls"
mw5girls = pd.DataFrame(mw5girls).T

mayWbwWL1Dfg = pd.concat([mw1girls,mw2girls,mw3girls,mw4girls,mw5girls])
mayWbwWL1Dfg
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\247951462.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw1girls = mayWeek1girls.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\247951462.py:12: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw2girls = mayWeek2girls.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\247951462.py:20: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw3girls = mayWeek3girls.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\247951462.py:28: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw4girls = mayWeek4girls.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\247951462.py:36: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw5girls = mayWeek5girls.sum()[1:]
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT             week  \
# 0     2.70   3.04   2.69  9.63        0.81    33.83  May Week 1 (5D)
# 0     3.69   4.17   3.68 13.06        1.13    47.56  May Week 2 (7D)
# 0     3.91   4.40   3.90 13.85        1.37    48.53  May Week 3 (7D)
# 0     4.29   4.80   4.28 15.15        1.50    50.90  May Week 4 (7D)
# 0     2.71   3.04   2.70  9.67        0.90    33.44  May Week 5 (5D)
#
#   LEV1GRPNAME
# 0       Girls
# 0       Girls
# 0       Girls
# 0       Girls
# 0       Girls

# %%
mayL1Dfg = mayWbwWL1Dfg.sum()[:-2]
mayL1Dfg["LEV1GRPNAME"] = "Girls"
mayL1Dfg = pd.DataFrame(mayL1Dfg).T
mayL1Dfg
# Out:
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT LEV1GRPNAME
# 0    17.31  19.45  17.25 61.36        5.72   214.26       Girls

# %%
start_date = '2024-05-01'
end_date = '2024-05-05'
mayWeek1infant = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Infant')]
mw1i = mayWeek1infant.sum()[1:]
mw1i["week"] = "May Week 1 (5D)"
mw1i["LEV1GRPNAME"] = "Infant"
mw1i = pd.DataFrame(mw1i).T

start_date = '2024-05-06'
end_date = '2024-05-12'
mayWeek2infant = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Infant')]
mw2i = mayWeek2infant.sum()[1:]
mw2i["week"] = "May Week 2 (7D)"
mw2i["LEV1GRPNAME"] = "Infant"
mw2i = pd.DataFrame(mw2i).T

start_date = '2024-05-13'
end_date = '2024-05-19'
mayWeek3infant = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Infant')]
mw3i = mayWeek3infant.sum()[1:]
mw3i["week"] = "May Week 3 (7D)"
mw3i["LEV1GRPNAME"] = "Infant"
mw3i = pd.DataFrame(mw3i).T

start_date = '2024-05-20'
end_date = '2024-05-26'
mayWeek4infant = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Infant')]
mw4i = mayWeek4infant.sum()[1:]
mw4i["week"] = "May Week 4 (7D)"
mw4i["LEV1GRPNAME"] = "Infant"
mw4i = pd.DataFrame(mw4i).T

start_date = '2024-05-27'
end_date = '2024-05-31'
mayWeek5infant = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Infant')]
mw5i = mayWeek5infant.sum()[1:]
mw5i["week"] = "May Week 5 (5D)"
mw5i["LEV1GRPNAME"] = "Infant"
mw5i = pd.DataFrame(mw5i).T

mayWbwWL1Dfi = pd.concat([mw1i,mw2i,mw3i,mw4i,mw5i])
mayWbwWL1Dfi
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\4158020234.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw1i = mayWeek1infant.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\4158020234.py:12: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw2i = mayWeek2infant.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\4158020234.py:20: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw3i = mayWeek3infant.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\4158020234.py:28: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw4i = mayWeek4infant.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\4158020234.py:36: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw5i = mayWeek5infant.sum()[1:]
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT             week  \
# 0     2.19   2.28   2.18 10.45        0.71     9.12  May Week 1 (5D)
# 0     3.09   3.23   3.08 14.65        1.00    13.17  May Week 2 (7D)
# 0     3.03   3.16   3.02 14.44        1.09    13.05  May Week 3 (7D)
# 0     3.05   3.20   3.04 14.64        1.04    14.77  May Week 4 (7D)
# 0     1.88   1.98   1.88  9.24        0.66     9.49  May Week 5 (5D)
#
#   LEV1GRPNAME
# 0      Infant
# 0      Infant
# 0      Infant
# 0      Infant
# 0      Infant

# %%
mayL1Dfi = mayWbwWL1Dfi.sum()[:-2]
mayL1Dfi["LEV1GRPNAME"] = "Infant"
mayL1Dfi = pd.DataFrame(mayL1Dfi).T
mayL1Dfi
# Out:
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT LEV1GRPNAME
# 0    13.25  13.84  13.20 63.42        4.50    59.60      Infant

# %%
start_date = '2024-05-01'
end_date = '2024-05-05'
mayWeek1we = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Women Ethnic')]
mw1we = mayWeek1we.sum()[1:]
mw1we["week"] = "May Week 1 (5D)"
mw1we["LEV1GRPNAME"] = "Women Ethenic"
mw1we = pd.DataFrame(mw1we).T

start_date = '2024-05-06'
end_date = '2024-05-12'
mayWeek2we = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Women Ethnic')]
mw2we = mayWeek2we.sum()[1:]
mw2we["week"] = "May Week 2 (7D)"
mw2we["LEV1GRPNAME"] = "Women Ethenic"
mw2we = pd.DataFrame(mw2we).T

start_date = '2024-05-13'
end_date = '2024-05-19'
mayWeek3we = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Women Ethnic')]
mw3we = mayWeek3we.sum()[1:]
mw3we["week"] = "May Week 3 (7D)"
mw3we["LEV1GRPNAME"] = "Women Ethenic"
mw3we = pd.DataFrame(mw3we).T

start_date = '2024-05-20'
end_date = '2024-05-26'
mayWeek4we = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Women Ethnic')]
mw4we = mayWeek4we.sum()[1:]
mw4we["week"] = "May Week 4 (7D)"
mw4we["LEV1GRPNAME"] = "Women Ethenic"
mw4we = pd.DataFrame(mw4we).T

start_date = '2024-05-27'
end_date = '2024-05-31'
mayWeek5we = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Women Ethnic')]
mw5we = mayWeek5we.sum()[1:]
mw5we["week"] = "May Week 5 (5D)"
mw5we["LEV1GRPNAME"] = "Women Ethenic"
mw5we = pd.DataFrame(mw5we).T

mayWbwWL1Dfwe = pd.concat([mw1we,mw2we,mw3we,mw4we,mw5we])
mayWbwWL1Dfwe
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\1237933155.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw1we = mayWeek1we.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\1237933155.py:12: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw2we = mayWeek2we.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\1237933155.py:20: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw3we = mayWeek3we.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\1237933155.py:28: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw4we = mayWeek4we.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\1237933155.py:36: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw5we = mayWeek5we.sum()[1:]
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT             week  \
# 0     4.83   5.85   4.82 11.04        1.11   101.43  May Week 1 (5D)
# 0     6.73   8.18   6.71 15.24        1.78   145.24  May Week 2 (7D)
# 0     6.39   7.78   6.37 14.55        1.73   138.75  May Week 3 (7D)
# 0     6.59   8.04   6.57 15.04        1.78   145.23  May Week 4 (7D)
# 0     4.16   5.16   4.15  9.83        1.14   100.18  May Week 5 (5D)
#
#      LEV1GRPNAME
# 0  Women Ethenic
# 0  Women Ethenic
# 0  Women Ethenic
# 0  Women Ethenic
# 0  Women Ethenic

# %%
mayL1Dfwe = mayWbwWL1Dfwe.sum()[:-2]
mayL1Dfwe["LEV1GRPNAME"] = "Women Ethenic"
mayL1Dfwe = pd.DataFrame(mayL1Dfwe).T
mayL1Dfwe
# Out:
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT    LEV1GRPNAME
# 0    28.70  35.01  28.62 65.70        7.54   630.83  Women Ethenic

# %%
groupDateDf = df.groupby(
    by=["BILLDATE"]
).agg({
    "GROSSAMT": "sum",
    "MRPAMT": "sum",
    "NETAMT": "sum",
    "QTY": "sum",
    "DISCOUNTAMT": "sum",
    "PROMOAMT": "sum"
}).reset_index()

# %%
groupDateDf[['GROSSAMT', 'MRPAMT', 'NETAMT']] = groupDateDf[['GROSSAMT', 'MRPAMT', 'NETAMT']]/10000000
groupDateDf[["QTY"]] = groupDateDf[["QTY"]]/10000 
groupDateDf[["DISCOUNTAMT", "PROMOAMT"]] = groupDateDf[["DISCOUNTAMT", "PROMOAMT"]]/100000

# %%
start_date = '2024-05-01'
end_date = '2024-05-05'
mayWeek1 = groupDateDf[(groupDateDf['BILLDATE'] >= start_date) & (groupDateDf['BILLDATE'] <= end_date)]
mayWeek1.sum()
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\3415540687.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mayWeek1.sum()
# GROSSAMT       32.16
# MRPAMT         36.36
# NETAMT         32.06
# QTY            97.39
# DISCOUNTAMT    10.25
# PROMOAMT      420.24
# dtype: float64

# %%
start_date = '2024-05-06'
end_date = '2024-05-12'
mayWeek2 = groupDateDf[(groupDateDf['BILLDATE'] >= start_date) & (groupDateDf['BILLDATE'] <= end_date)]
mayWeek2.sum()
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\4161800422.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mayWeek2.sum()
# GROSSAMT       43.98
# MRPAMT         49.81
# NETAMT         43.83
# QTY           132.55
# DISCOUNTAMT    14.85
# PROMOAMT      583.15
# dtype: float64

# %%
start_date = '2024-05-13'
end_date = '2024-05-19'
mayWeek3 = groupDateDf[(groupDateDf['BILLDATE'] >= start_date) & (groupDateDf['BILLDATE'] <= end_date)]
mayWeek3.sum()
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\2068628789.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mayWeek3.sum()
# GROSSAMT       44.04
# MRPAMT         49.77
# NETAMT         43.89
# QTY           135.39
# DISCOUNTAMT    15.59
# PROMOAMT      572.59
# dtype: float64

# %%
start_date = '2024-05-20'
end_date = '2024-05-26'
mayWeek4 = groupDateDf[(groupDateDf['BILLDATE'] >= start_date) & (groupDateDf['BILLDATE'] <= end_date)]
mayWeek4.sum()
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\4014494179.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mayWeek4.sum()
# GROSSAMT       45.94
# MRPAMT         51.85
# NETAMT         45.78
# QTY           142.00
# DISCOUNTAMT    16.05
# PROMOAMT      591.60
# dtype: float64

# %%
start_date = '2024-05-27'
end_date = '2024-05-31'
mayWeek5 = groupDateDf[(groupDateDf['BILLDATE'] >= start_date) & (groupDateDf['BILLDATE'] <= end_date)]
mayWeek5.sum().T
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\1824364219.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mayWeek5.sum().T
# GROSSAMT       29.08
# MRPAMT         32.93
# NETAMT         28.98
# QTY            92.07
# DISCOUNTAMT    10.41
# PROMOAMT      385.01
# dtype: float64

# %%
mw1 = mayWeek1.sum()
mw1["week"] = "May Week 1 (5D)"
mw1 = pd.DataFrame(mw1).T

mw2 = mayWeek2.sum()
mw2["week"] = "May Week 2 (7D)"
mw2 = pd.DataFrame(mw2).T

mw3 = mayWeek3.sum()
mw3["week"] = "May Week 3 (7D)"
mw3 = pd.DataFrame(mw3).T

mw4 = mayWeek4.sum()
mw4["week"] = "May Week 4 (7D)"
mw4 = pd.DataFrame(mw4).T

mw5 = mayWeek5.sum()
mw5["week"] = "May Week 5 (5D)"
mw5 = pd.DataFrame(mw5).T
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\3679312491.py:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw1 = mayWeek1.sum()
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\3679312491.py:5: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw2 = mayWeek2.sum()
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\3679312491.py:9: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw3 = mayWeek3.sum()
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\3679312491.py:13: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw4 = mayWeek4.sum()
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_7928\3679312491.py:17: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw5 = mayWeek5.sum()

# %%
mayWbwDf = pd.concat([mw1,mw2,mw3,mw4,mw5])
mayWbwDf
# Out:
#   GROSSAMT MRPAMT NETAMT    QTY DISCOUNTAMT PROMOAMT             week
# 0    32.16  36.36  32.06  97.39       10.25   420.24  May Week 1 (5D)
# 0    43.98  49.81  43.83 132.55       14.85   583.15  May Week 2 (7D)
# 0    44.04  49.77  43.89 135.39       15.59   572.59  May Week 3 (7D)
# 0    45.94  51.85  45.78 142.00       16.05   591.60  May Week 4 (7D)
# 0    29.08  32.93  28.98  92.07       10.41   385.01  May Week 5 (5D)

# %%
may = mayWbwDf.sum()[:-1]
may = pd.DataFrame(may).T
may
# Out:
#   GROSSAMT MRPAMT NETAMT    QTY DISCOUNTAMT PROMOAMT
# 0   195.20 220.73 194.53 599.40       67.15  2552.59

# %%
may.rename(columns={
    "GROSSAMT": "GROSSAMT (Cr)", 
    "MRPAMT": "MRPAMT (Cr)", 
    "NETAMT": "NETAMT (Cr)", 
    "QTY": "QTY (Tth)", 
    "DISCOUNTAMT": "DISCOUNTAMT (lac)", 
    "PROMOAMT": "PROMOAMT (lac)"
}, inplace=True)
may.to_csv(r"May/may.csv")

# %%
mayWbwDf.rename(columns={
    "GROSSAMT": "GROSSAMT (Cr)", 
    "MRPAMT": "MRPAMT (Cr)", 
    "NETAMT": "NETAMT (Cr)", 
    "QTY": "QTY (Tth)", 
    "DISCOUNTAMT": "DISCOUNTAMT (lac)", 
    "PROMOAMT": "PROMOAMT (lac)"
}, inplace=True)
mayWbwDf
# Out:
#   GROSSAMT (Cr) MRPAMT (Cr) NETAMT (Cr) QTY (Tth) DISCOUNTAMT (lac)  \
# 0         32.16       36.36       32.06     97.39             10.25
# 0         43.98       49.81       43.83    132.55             14.85
# 0         44.04       49.77       43.89    135.39             15.59
# 0         45.94       51.85       45.78    142.00             16.05
# 0         29.08       32.93       28.98     92.07             10.41
#
#   PROMOAMT (lac)             week
# 0         420.24  May Week 1 (5D)
# 0         583.15  May Week 2 (7D)
# 0         572.59  May Week 3 (7D)
# 0         591.60  May Week 4 (7D)
# 0         385.01  May Week 5 (5D)

# %%
mayWbwDf.to_csv(r"May/weekByWeek.csv")

# %%
mayWbwWL1Df = pd.concat([mayWbwWL1Dfm,mayWbwWL1Dfb,mayWbwWL1Dfww,mayWbwWL1Dfg,mayWbwWL1Dfi,mayWbwWL1Dfwe])
mayWbwWL1Df
# Out:
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT             week  \
# 0    13.49  15.16  13.44 34.36        4.95   167.16  May Week 1 (5D)
# 0    18.21  20.51  18.14 46.17        7.18   229.61  May Week 2 (7D)
# 0    17.81  19.99  17.74 46.44        7.10   218.18  May Week 3 (7D)
# 0    18.13  20.23  18.06 47.41        7.17   210.50  May Week 4 (7D)
# 0    13.49  15.16  13.44 34.36        4.95   167.16  May Week 5 (5D)
# 0     3.79   4.36   3.78 14.77        1.21    56.50  May Week 1 (5D)
# 0     5.28   6.07   5.26 20.43        1.71    79.24  May Week 2 (7D)
# 0     5.61   6.45   5.59 21.85        1.99    84.09  May Week 3 (7D)
# 0     6.13   7.05   6.11 23.85        2.20    92.41  May Week 4 (7D)
# 0     3.79   4.36   3.78 14.77        1.21    56.50  May Week 5 (5D)
# 0     5.16   5.68   5.14 17.14        1.46    52.20  May Week 1 (5D)
# 0     6.97   7.65   6.95 23.01        2.05    68.33  May Week 2 (7D)
# 0     7.29   7.99   7.26 24.26        2.31    70.00  May Week 3 (7D)
# 0     7.75   8.53   7.72 25.91        2.36    77.80  May Week 4 (7D)
# 0     4.93   5.45   4.91 16.81        1.50    51.84  May Week 5 (5D)
# 0     2.70   3.04   2.69  9.63        0.81    33.83  May Week 1 (5D)
# 0     3.69   4.17   3.68 13.06        1.13    47.56  May Week 2 (7D)
# 0     3.91   4.40   3.90 13.85        1.37    48.53  May Week 3 (7D)
# 0     4.29   4.80   4.28 15.15        1.50    50.90  May Week 4 (7D)
# 0     2.71   3.04   2.70  9.67        0.90    33.44  May Week 5 (5D)
# 0     2.19   2.28   2.18 10.45        0.71     9.12  May Week 1 (5D)
# 0     3.09   3.23   3.08 14.65        1.00    13.17  May Week 2 (7D)
# 0     3.03   3.16   3.02 14.44        1.09    13.05  May Week 3 (7D)
# 0     3.05   3.20   3.04 14.64        1.04    14.77  May Week 4 (7D)
# 0     1.88   1.98   1.88  9.24        0.66     9.49  May Week 5 (5D)
# 0     4.83   5.85   4.82 11.04        1.11   101.43  May Week 1 (5D)
# 0     6.73   8.18   6.71 15.24        1.78   145.24  May Week 2 (7D)
# 0     6.39   7.78   6.37 14.55        1.73   138.75  May Week 3 (7D)
# 0     6.59   8.04   6.57 15.04        1.78   145.23  May Week 4 (7D)
# 0     4.16   5.16   4.15  9.83        1.14   100.18  May Week 5 (5D)
#
#      LEV1GRPNAME
# 0            Men
# 0            Men
# 0            Men
# 0            Men
# 0            Men
# 0           Boys
# 0           Boys
# 0           Boys
# 0           Boys
# 0           Boys
# 0   Wester Women
# 0   Wester Women
# 0   Wester Women
# 0   Wester Women
# 0   Wester Women
# 0          Girls
# 0          Girls
# 0          Girls
# 0          Girls
# 0          Girls
# 0         Infant
# 0         Infant
# 0         Infant
# 0         Infant
# 0         Infant
# 0  Women Ethenic
# 0  Women Ethenic
# 0  Women Ethenic
# 0  Women Ethenic
# 0  Women Ethenic

# %%
mayWbwWL1Df.to_csv(r"May/weekByWeekWithL1.csv")

# %%
mayL1Df = pd.concat([mayL1Dfm,mayL1Dfb,mayL1Dfww,mayL1Dfg,mayL1Dfi,mayL1Dfwe])
mayL1Df
# Out:
#   GROSSAMT MRPAMT NETAMT    QTY DISCOUNTAMT PROMOAMT    LEV1GRPNAME
# 0    81.13  91.05  80.81 208.73       31.36   992.61            Men
# 0    24.59  28.28  24.51  95.68        8.32   368.74           Boys
# 0    32.09  35.29  31.99 107.13        9.67   320.16   Wester Women
# 0    17.31  19.45  17.25  61.36        5.72   214.26          Girls
# 0    13.25  13.84  13.20  63.42        4.50    59.60         Infant
# 0    28.70  35.01  28.62  65.70        7.54   630.83  Women Ethenic

# %%
mayL1Df.to_csv(r"May/mayL1.csv")

# %%
mayDf.groupby(by=["GRPNAME"]).agg({"QTY": "sum"}).reset_index().to_csv("categoryCountMay.csv")
