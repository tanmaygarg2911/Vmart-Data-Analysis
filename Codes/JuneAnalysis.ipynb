# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
juneDf = pd.read_csv("juneDf.csv")
juneDf
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_12876\3991370934.py:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   juneDf = pd.read_csv("juneDf.csv")
#          Unnamed: 0 UDFSTRING15         OPH3                 SHRTNAME  \
# 0                 0     DIGITAL           TN          CHROMPET_BIG MM
# 1                 1     DIGITAL         UP11      BAREILLY-RAM VATIKA
# 2                 2     DIGITAL           TS                WARRANGAL
# 3                 3     DIGITAL          KAR                   TUMKUR
# 4                 4     DIGITAL           TN                  MADURAI
# ...             ...         ...          ...                      ...
# 6014757      236513     DIGITAL           TN             THORAIPAKKAM
# 6014758      236514     DIGITAL           AP                 KAKINADA
# 6014759      236515         NaN  RAJASTHAN-2  JODHPUR-AKHALIYA CIRCLE
# 6014760      236516     DIGITAL          UP8               THAKURGANJ
# 6014761      236517     DIGITAL          UP8               THAKURGANJ
#
#          ADM_SITE_CODE    BILLDATE LEV1GRPNAME       LEV2GRPNAME  \
# 0            101538.00  2024-06-01         Men  Mens Sports Wear
# 1            102548.00  2024-06-01         Men        Mens Upper
# 2            101568.00  2024-06-01        Boys       Boys Senior
# 3            101521.00  2024-06-01         Men        Mens Upper
# 4            101545.00  2024-06-01         Men        Mens Upper
# ...                ...         ...         ...               ...
# 6014757      101552.00  2024-06-30       Girls      Girls Junior
# 6014758      101504.00  2024-06-30       Girls      Girls Junior
# 6014759      102526.00  2024-06-30       Girls      Girls Junior
# 6014760      101065.00  2024-06-30       Girls      Girls Junior
# 6014761      101065.00  2024-06-30       Girls      Girls Junior
#
#                  GRPNAME  ARTICLECODE  ... UDFSTRING07  UDFSTRING08  \
# 0               Sando[M]        25.00  ...         NaN          NaN
# 1          T-Shirt FS[M]      2650.00  ...    ALL OVER      REGULAR
# 2            T-Shirt[BS]     15544.00  ...       PLAIN      REGULAR
# 3        Casual Shirt[M]     57416.00  ...         NaN      REGULAR
# 4        Casual Shirt[M]     57416.00  ...         NaN      REGULAR
# ...                  ...          ...  ...         ...          ...
# 6014757       Pyjama[GJ]     17389.00  ...         NaN  FULL LENGTH
# 6014758       Pyjama[GJ]     17389.00  ...         NaN  FULL LENGTH
# 6014759      T-Shirt[GJ]     52079.00  ...    ALL OVER      REGULAR
# 6014760      T-Shirt[GJ]     52079.00  ...    ALL OVER      REGULAR
# 6014761      T-Shirt[GJ]     52079.00  ...    ALL OVER      REGULAR
#
#         UDFSTRING09 UDFSTRING10 GROSSAMT MRPAMT NETAMT  QTY DISCOUNTAMT  \
# 0               NaN         NaN   249.00 249.00 249.00 1.00        0.00
# 1               NaN         NaN   186.75 249.00 186.75 1.00        0.00
# 2               NaN         NaN    96.75 129.00  96.75 1.00        0.00
# 3               NaN         NaN   499.00 499.00 499.00 1.00        0.00
# 4               NaN         NaN     0.01 499.00   0.01 1.00        0.00
# ...             ...         ...      ...    ...    ...  ...         ...
# 6014757         NaN         NaN   349.00 349.00 349.00 1.00        0.00
# 6014758         NaN         NaN   349.00 349.00 174.82 1.00      174.18
# 6014759         NaN         NaN    99.00  99.00  99.00 1.00        0.00
# 6014760         NaN         NaN    99.00  99.00  99.00 1.00        0.00
# 6014761         NaN         NaN    99.00  99.00  99.00 1.00        0.00
#
#         PROMOAMT
# 0           0.00
# 1          62.25
# 2          32.25
# 3           0.00
# 4         498.99
# ...          ...
# 6014757     0.00
# 6014758     0.00
# 6014759     0.00
# 6014760     0.00
# 6014761     0.00
#
# [6014762 rows x 34 columns]

# %%
df = juneDf.groupby(by=["GRPNAME"]).agg({"QTY": "sum"}).reset_index().to_csv("categoryCountJune.csv")

# %%
df = juneDf[['LEV1GRPNAME','BILLDATE','GROSSAMT', 'MRPAMT', 'NETAMT', 'QTY', 'DISCOUNTAMT', 'PROMOAMT']]
df
# Out:
#         LEV1GRPNAME    BILLDATE  GROSSAMT  MRPAMT  NETAMT  QTY  DISCOUNTAMT  \
# 0               Men  2024-06-01    249.00  249.00  249.00 1.00         0.00
# 1               Men  2024-06-01    186.75  249.00  186.75 1.00         0.00
# 2              Boys  2024-06-01     96.75  129.00   96.75 1.00         0.00
# 3               Men  2024-06-01    499.00  499.00  499.00 1.00         0.00
# 4               Men  2024-06-01      0.01  499.00    0.01 1.00         0.00
# ...             ...         ...       ...     ...     ...  ...          ...
# 6014757       Girls  2024-06-30    349.00  349.00  349.00 1.00         0.00
# 6014758       Girls  2024-06-30    349.00  349.00  174.82 1.00       174.18
# 6014759       Girls  2024-06-30     99.00   99.00   99.00 1.00         0.00
# 6014760       Girls  2024-06-30     99.00   99.00   99.00 1.00         0.00
# 6014761       Girls  2024-06-30     99.00   99.00   99.00 1.00         0.00
#
#          PROMOAMT
# 0            0.00
# 1           62.25
# 2           32.25
# 3            0.00
# 4          498.99
# ...           ...
# 6014757      0.00
# 6014758      0.00
# 6014759      0.00
# 6014760      0.00
# 6014761      0.00
#
# [6014762 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6014762 entries, 0 to 6014761
# Data columns (total 8 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   LEV1GRPNAME  object
#  1   BILLDATE     object
#  2   GROSSAMT     float64
#  3   MRPAMT       float64
#  4   NETAMT       float64
#  5   QTY          float64
#  6   DISCOUNTAMT  float64
#  7   PROMOAMT     float64
# dtypes: float64(6), object(2)
# memory usage: 367.1+ MB

# %%
df["BILLDATE"] = pd.to_datetime(df["BILLDATE"])
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\811933721.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["BILLDATE"] = pd.to_datetime(df["BILLDATE"])

# %%
df[['GROSSAMT', 'MRPAMT', 'NETAMT', 'QTY', 'DISCOUNTAMT', 'PROMOAMT']].isnull().sum()
# Out:
# GROSSAMT       0
# MRPAMT         0
# NETAMT         0
# QTY            0
# DISCOUNTAMT    0
# PROMOAMT       0
# dtype: int64

# %%
df[(df['GROSSAMT']<0) | (df['MRPAMT']<0) | (df['NETAMT']<0) | (df['QTY']<0) | (df['DISCOUNTAMT']<0) | (df['PROMOAMT']<0)]
# Out:
#            LEV1GRPNAME   BILLDATE  GROSSAMT  MRPAMT  NETAMT   QTY  \
# 27       Women Western 2024-06-01   -799.00 -799.00 -799.00 -1.00
# 40                 Men 2024-06-01   -449.00 -449.00 -449.00 -1.00
# 81                 Men 2024-06-01   -299.00 -299.00 -299.00 -1.00
# 130              Girls 2024-06-01   -549.00 -549.00 -549.00 -1.00
# 209                Men 2024-06-01   -499.00 -499.00 -499.00 -1.00
# ...                ...        ...       ...     ...     ...   ...
# 6014569   Women Ethnic 2024-06-30   -449.25 -599.00 -449.25 -1.00
# 6014601  Women Western 2024-06-30   -224.25 -299.00 -224.25 -1.00
# 6014602            Men 2024-06-30   -799.00 -799.00 -799.00 -1.00
# 6014607  Women Western 2024-06-30   -499.00 -499.00 -499.00 -1.00
# 6014751         Infant 2024-06-30   -224.25 -299.00 -224.25 -1.00
#
#          DISCOUNTAMT  PROMOAMT
# 27              0.00      0.00
# 40              0.00      0.00
# 81              0.00      0.00
# 130             0.00      0.00
# 209             0.00      0.00
# ...              ...       ...
# 6014569         0.00   -149.75
# 6014601         0.00    -74.75
# 6014602         0.00      0.00
# 6014607         0.00      0.00
# 6014751         0.00    -74.75
#
# [164384 rows x 8 columns]

# %%
df["LEV1GRPNAME"].unique()
# Out:
# array(['Men', 'Boys', 'Women Western', 'Infant', 'Women Ethnic', 'Girls'],
#       dtype=object)

# %%
groupL1nDateDf = df.groupby(
    by=["LEV1GRPNAME", "BILLDATE"]
).agg({
    "GROSSAMT": "sum",
    "MRPAMT": "sum",
    "NETAMT": "sum",
    "QTY": "sum",
    "DISCOUNTAMT": "sum",
    "PROMOAMT": "sum"
}).reset_index()

# %%
groupL1nDateDf[['GROSSAMT', 'MRPAMT', 'NETAMT']] = groupL1nDateDf[['GROSSAMT', 'MRPAMT', 'NETAMT']]/10000000

# %%
groupL1nDateDf[["QTY"]] = groupL1nDateDf[["QTY"]]/10000 
groupL1nDateDf[["DISCOUNTAMT", "PROMOAMT"]] = groupL1nDateDf[["DISCOUNTAMT", "PROMOAMT"]]/100000

# %%
groupL1nDateDf[groupL1nDateDf['LEV1GRPNAME'] == 'Men']
# Out:
#     LEV1GRPNAME   BILLDATE  GROSSAMT  MRPAMT  NETAMT   QTY  DISCOUNTAMT  \
# 90          Men 2024-06-01      2.76    3.11    2.75  6.93         0.99
# 91          Men 2024-06-02      3.97    4.49    3.95  9.94         1.32
# 92          Men 2024-06-03      2.46    2.75    2.45  6.46         0.83
# 93          Men 2024-06-04      1.93    2.14    1.92  5.01         0.71
# 94          Men 2024-06-05      2.34    2.63    2.33  6.07         0.84
# 95          Men 2024-06-06      2.33    2.63    2.32  5.95         0.79
# 96          Men 2024-06-07      2.56    2.91    2.55  6.41         0.78
# 97          Men 2024-06-08      3.14    3.61    3.13  7.69         1.16
# 98          Men 2024-06-09      3.60    4.15    3.59  8.96         1.32
# 99          Men 2024-06-10      2.32    2.62    2.31  6.11         0.87
# 100         Men 2024-06-11      2.45    2.76    2.44  6.46         0.85
# 101         Men 2024-06-12      2.44    2.76    2.43  6.42         0.80
# 102         Men 2024-06-13      3.25    3.53    2.80  7.02        44.17
# 103         Men 2024-06-14      3.34    3.64    2.88  7.14        46.90
# 104         Men 2024-06-15      4.60    4.95    3.77  8.75        82.80
# 105         Men 2024-06-16      6.11    6.61    5.07 11.83       103.72
# 106         Men 2024-06-17      3.10    3.37    2.63  6.45        47.67
# 107         Men 2024-06-18      2.51    2.75    2.21  5.68        30.39
# 108         Men 2024-06-19      2.54    2.79    2.24  5.74        29.84
groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Men')]
mw2m = juneWeek2men.sum()[1:]
mw2m["week"] = "June Week 2 (7D)"
mw2m["LEV1GRPNAME"] = "Men"
mw2m = pd.DataFrame(mw2m).T

start_date = '2024-06-10'
end_date = '2024-06-16'
juneWeek3men = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Men')]
mw3m = juneWeek3men.sum()[1:]
mw3m["week"] = "June Week 3 (7D)"
mw3m["LEV1GRPNAME"] = "Men"
mw3m = pd.DataFrame(mw3m).T

start_date = '2024-06-17'
end_date = '2024-06-23'
juneWeek4men = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Men')]
mw4m = juneWeek4men.sum()[1:]
mw4m["week"] = "June Week 4 (7D)"
mw4m["LEV1GRPNAME"] = "Men"
mw4m = pd.DataFrame(mw4m).T

start_date = '2024-06-24'
end_date = '2024-06-30'
juneWeek5men = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Men')]
mw5m = juneWeek1men.sum()[1:]
mw5m["week"] = "June Week 5 (7D)"
mw5m["LEV1GRPNAME"] = "Men"
mw5m = pd.DataFrame(mw5m).T

juneWbwWL1Dfm = pd.concat([mw1m,mw2m,mw3m,mw4m,mw5m])
juneWbwWL1Dfm
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\150034900.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw1m = juneWeek1men.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\150034900.py:12: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw2m = juneWeek2men.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\150034900.py:20: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw3m = juneWeek3men.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\150034900.py:28: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw4m = juneWeek4men.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\150034900.py:36: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw5m = juneWeek1men.sum()[1:]
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT              week  \
# 0     6.73   7.60   6.71 16.87        2.32    86.86  June Week 1 (2D)
# 0    18.35  20.82  18.28 46.55        6.43   247.32  June Week 2 (7D)
# 0    24.50  26.87  21.70 53.73      280.11   237.38  June Week 3 (7D)
# 0    20.92  22.94  18.03 44.80      289.08   201.78  June Week 4 (7D)
# 0     6.73   7.60   6.71 16.87        2.32    86.86  June Week 5 (7D)
#
#   LEV1GRPNAME
# 0         Men
# 0         Men
# 0         Men
# 0         Men
# 0         Men

# %%
mayL1Dfm = juneWbwWL1Dfm.sum()[:-2]
mayL1Dfm["LEV1GRPNAME"] = "Men"
mayL1Dfm = pd.DataFrame(mayL1Dfm).T
mayL1Dfm
# Out:
#   GROSSAMT MRPAMT NETAMT    QTY DISCOUNTAMT PROMOAMT LEV1GRPNAME
# 0    77.23  85.83  71.43 178.82      580.26   860.20         Men

# %%
start_date = '2024-06-01'
end_date = '2024-06-02'
mayWeek1boys = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Boys')]
mw1b = mayWeek1boys.sum()[1:]
mw1b["week"] = "June Week 1 (2D)"
mw1b["LEV1GRPNAME"] = "Boys"
mw1b = pd.DataFrame(mw1b).T

start_date = '2024-06-03'
end_date = '2024-06-09'
mayWeek2boys = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Boys')]
mw2b = mayWeek2boys.sum()[1:]
mw2b["week"] = "June Week 2 (7D)"
mw2b["LEV1GRPNAME"] = "Boys"
mw2b = pd.DataFrame(mw2b).T

start_date = '2024-06-10'
end_date = '2024-06-16'
mayWeek3boys = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Boys')]
mw3b = mayWeek3boys.sum()[1:]
mw3b["week"] = "June Week 3 (7D)"
mw3b["LEV1GRPNAME"] = "Boys"
mw3b = pd.DataFrame(mw3b).T

start_date = '2024-06-17'
end_date = '2024-06-23'
mayWeek4boys = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Boys')]
mw4b = mayWeek4boys.sum()[1:]
mw4b["week"] = "June Week 4 (7D)"
mw4b["LEV1GRPNAME"] = "Boys"
mw4b = pd.DataFrame(mw4b).T

start_date = '2024-06-24'
end_date = '2024-06-30'
mayWeek5boys = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Boys')]
mw5b = mayWeek1boys.sum()[1:]
mw5b["week"] = "June Week 5 (7D)"
mw5b["LEV1GRPNAME"] = "Boys"
mw5b = pd.DataFrame(mw5b).T

mayWbwWL1Dfb = pd.concat([mw1b,mw2b,mw3b,mw4b,mw5b])
mayWbwWL1Dfb
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\1222481390.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw1b = mayWeek1boys.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\1222481390.py:12: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw2b = mayWeek2boys.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\1222481390.py:20: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw3b = mayWeek3boys.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\1222481390.py:28: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw4b = mayWeek4boys.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\1222481390.py:36: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw5b = mayWeek1boys.sum()[1:]
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT              week  \
# 0     2.15   2.50   2.14  8.33        0.59    35.09  June Week 1 (2D)
# 0     6.18   7.15   6.16 24.03        1.82    97.73  June Week 2 (7D)
# 0     7.42   8.39   7.19 27.58       23.17    96.32  June Week 3 (7D)
# 0     4.98   5.59   4.77 18.39       21.10    61.18  June Week 4 (7D)
# 0     2.15   2.50   2.14  8.33        0.59    35.09  June Week 5 (7D)
#
#   LEV1GRPNAME
# 0        Boys
# 0        Boys
# 0        Boys
# 0        Boys
# 0        Boys

# %%
mayL1Dfb = mayWbwWL1Dfb.sum()[:-2]
mayL1Dfb["LEV1GRPNAME"] = "Boys"
mayL1Dfb = pd.DataFrame(mayL1Dfb).T
mayL1Dfb
# Out:
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT LEV1GRPNAME
# 0    22.88  26.13  22.40 86.65       47.26   325.40        Boys

# %%
start_date = '2024-06-01'
end_date = '2024-06-02'
mayWeek1ww = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Women Western')]
mw1ww = mayWeek1ww.sum()[1:]
mw1ww["week"] = "June Week 1 (2D)"
mw1ww["LEV1GRPNAME"] = "Wester Women"
mw1ww = pd.DataFrame(mw1ww).T

start_date = '2024-06-03'
end_date = '2024-06-09'
mayWeek2ww = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Women Western')]
mw2ww = mayWeek2ww.sum()[1:]
mw2ww["week"] = "June Week 2 (7D)"
mw2ww["LEV1GRPNAME"] = "Wester Women"
mw2ww = pd.DataFrame(mw2ww).T

start_date = '2024-06-10'
end_date = '2024-06-16'
mayWeek3ww = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Women Western')]
mw3ww = mayWeek3ww.sum()[1:]
mw3ww["week"] = "June Week 3 (7D)"
mw3ww["LEV1GRPNAME"] = "Wester Women"
mw3ww = pd.DataFrame(mw3ww).T

start_date = '2024-06-17'
end_date = '2024-06-23'
mayWeek4ww = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Women Western')]
mw4ww = mayWeek4ww.sum()[1:]
mw4ww["week"] = "June Week 4 (7D)"
mw4ww["LEV1GRPNAME"] = "Wester Women"
mw4ww = pd.DataFrame(mw4ww).T

start_date = '2024-06-24'
end_date = '2024-06-30'
mayWeek5ww = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Women Western')]
mw5ww = mayWeek5ww.sum()[1:]
mw5ww["week"] = "June Week 5 (7D)"
mw5ww["LEV1GRPNAME"] = "Wester Women"
mw5ww = pd.DataFrame(mw5ww).T

mayWbwWL1Dfww = pd.concat([mw1ww,mw2ww,mw3ww,mw4ww,mw5ww])
mayWbwWL1Dfww
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\1333642619.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw1ww = mayWeek1ww.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\1333642619.py:12: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw2ww = mayWeek2ww.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\1333642619.py:20: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw3ww = mayWeek3ww.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\1333642619.py:28: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw4ww = mayWeek4ww.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\1333642619.py:36: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw5ww = mayWeek5ww.sum()[1:]
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT              week  \
# 0     2.67   2.95   2.66  8.61        0.67    28.23  June Week 1 (2D)
# 0     7.02   7.80   7.00 22.32        1.97    77.87  June Week 2 (7D)
# 0     7.36   8.07   7.14 22.49       21.91    70.95  June Week 3 (7D)
# 0     6.48   7.07   6.23 20.53       24.74    58.85  June Week 4 (7D)
# 0     5.81   6.34   5.55 17.83       26.05    52.29  June Week 5 (7D)
#
#     LEV1GRPNAME
# 0  Wester Women
# 0  Wester Women
# 0  Wester Women
# 0  Wester Women
# 0  Wester Women

# %%
mayL1Dfww = mayWbwWL1Dfww.sum()[:-2]
mayL1Dfww["LEV1GRPNAME"] = "Wester Women"
mayL1Dfww = pd.DataFrame(mayL1Dfww).T
mayL1Dfww
# Out:
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT   LEV1GRPNAME
# 0    29.34  32.22  28.59 91.77       75.33   288.19  Wester Women

# %%
start_date = '2024-06-01'
end_date = '2024-06-02'
mayWeek1girls = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Girls')]
mw1girls = mayWeek1girls.sum()[1:]
mw1girls["week"] = "June Week 1 (2D)"
mw1girls["LEV1GRPNAME"] = "Girls"
mw1girls = pd.DataFrame(mw1girls).T

start_date = '2024-06-03'
end_date = '2024-06-09'
mayWeek2girls = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Girls')]
mw2girls = mayWeek2girls.sum()[1:]
mw2girls["week"] = "June Week 2 (7D)"
mw2girls["LEV1GRPNAME"] = "Girls"
mw2girls = pd.DataFrame(mw2girls).T

start_date = '2024-06-10'
end_date = '2024-06-16'
mayWeek3girls = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Girls')]
mw3girls = mayWeek3girls.sum()[1:]
mw3girls["week"] = "June Week 3 (7D)"
mw3girls["LEV1GRPNAME"] = "Girls"
mw3girls = pd.DataFrame(mw3girls).T

start_date = '2024-06-17'
end_date = '2024-06-23'
mayWeek4girls = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Girls')]
mw4girls = mayWeek4girls.sum()[1:]
mw4girls["week"] = "June Week 4 (7D)"
mw4girls["LEV1GRPNAME"] = "Girls"
mw4girls = pd.DataFrame(mw4girls).T

start_date = '2024-06-24'
end_date = '2024-06-30'
mayWeek5girls = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Girls')]
mw5girls = mayWeek5girls.sum()[1:]
mw5girls["week"] = "June Week 5 (7D)"
mw5girls["LEV1GRPNAME"] = "Girls"
mw5girls = pd.DataFrame(mw5girls).T

mayWbwWL1Dfg = pd.concat([mw1girls,mw2girls,mw3girls,mw4girls,mw5girls])
mayWbwWL1Dfg
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\2143452608.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw1girls = mayWeek1girls.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\2143452608.py:12: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw2girls = mayWeek2girls.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\2143452608.py:20: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw3girls = mayWeek3girls.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\2143452608.py:28: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw4girls = mayWeek4girls.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\2143452608.py:36: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw5girls = mayWeek5girls.sum()[1:]
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT              week  \
# 0     1.53   1.72   1.53  5.34        0.38    19.00  June Week 1 (2D)
# 0     4.28   4.78   4.26 14.70        1.24    50.15  June Week 2 (7D)
# 0     5.11   5.63   4.95 16.77       15.87    52.65  June Week 3 (7D)
# 0     3.35   3.68   3.18 11.19       17.54    32.30  June Week 4 (7D)
# 0     3.04   3.33   2.85  9.91       18.50    29.63  June Week 5 (7D)
#
#   LEV1GRPNAME
# 0       Girls
# 0       Girls
# 0       Girls
# 0       Girls
# 0       Girls

# %%
mayL1Dfg = mayWbwWL1Dfg.sum()[:-2]
mayL1Dfg["LEV1GRPNAME"] = "Girls"
mayL1Dfg = pd.DataFrame(mayL1Dfg).T
mayL1Dfg
# Out:
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT LEV1GRPNAME
# 0    17.31  19.14  16.77 57.91       53.53   183.72       Girls

# %%
start_date = '2024-06-01'
end_date = '2024-06-02'
mayWeek1infant = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Infant')]
mw1i = mayWeek1infant.sum()[1:]
mw1i["week"] = "June Week 1 (2D)"
mw1i["LEV1GRPNAME"] = "Infant"
mw1i = pd.DataFrame(mw1i).T

start_date = '2024-06-03'
end_date = '2024-06-09'
mayWeek2infant = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Infant')]
mw2i = mayWeek2infant.sum()[1:]
mw2i["week"] = "June Week 2 (7D)"
mw2i["LEV1GRPNAME"] = "Infant"
mw2i = pd.DataFrame(mw2i).T

start_date = '2024-06-10'
end_date = '2024-06-16'
mayWeek3infant = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Infant')]
mw3i = mayWeek3infant.sum()[1:]
mw3i["week"] = "June Week 3 (7D)"
mw3i["LEV1GRPNAME"] = "Infant"
mw3i = pd.DataFrame(mw3i).T

start_date = '2024-06-17'
end_date = '2024-06-23'
mayWeek4infant = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Infant')]
mw4i = mayWeek4infant.sum()[1:]
mw4i["week"] = "June Week 4 (7D)"
mw4i["LEV1GRPNAME"] = "Infant"
mw4i = pd.DataFrame(mw4i).T

start_date = '2024-06-24'
end_date = '2024-06-30'
mayWeek5infant = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Infant')]
mw5i = mayWeek5infant.sum()[1:]
mw5i["week"] = "June Week 5 (7D)"
mw5i["LEV1GRPNAME"] = "Infant"
mw5i = pd.DataFrame(mw5i).T

mayWbwWL1Dfi = pd.concat([mw1i,mw2i,mw3i,mw4i,mw5i])
mayWbwWL1Dfi
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\3772950845.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw1i = mayWeek1infant.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\3772950845.py:12: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw2i = mayWeek2infant.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\3772950845.py:20: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw3i = mayWeek3infant.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\3772950845.py:28: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw4i = mayWeek4infant.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\3772950845.py:36: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw5i = mayWeek5infant.sum()[1:]
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT              week  \
# 0     1.02   1.07   1.02  4.89        0.30     5.29  June Week 1 (2D)
# 0     2.96   3.12   2.95 14.17        0.92    15.31  June Week 2 (7D)
# 0     3.58   3.77   3.54 16.65        3.88    19.01  June Week 3 (7D)
# 0     2.50   2.62   2.47 11.72        3.71    11.66  June Week 4 (7D)
# 0     2.43   2.53   2.39 11.26        3.91    10.28  June Week 5 (7D)
#
#   LEV1GRPNAME
# 0      Infant
# 0      Infant
# 0      Infant
# 0      Infant
# 0      Infant

# %%
mayL1Dfi = mayWbwWL1Dfi.sum()[:-2]
mayL1Dfi["LEV1GRPNAME"] = "Infant"
mayL1Dfi = pd.DataFrame(mayL1Dfi).T
mayL1Dfi
# Out:
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT LEV1GRPNAME
# 0    12.50  13.11  12.37 58.69       12.70    61.53      Infant

# %%
start_date = '2024-06-01'
end_date = '2024-06-02'
mayWeek1we = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Women Ethnic')]
mw1we = mayWeek1we.sum()[1:]
mw1we["week"] = "June Week 1 (2D)"
mw1we["LEV1GRPNAME"] = "Women Ethenic"
mw1we = pd.DataFrame(mw1we).T

start_date = '2024-06-03'
end_date = '2024-06-09'
mayWeek2we = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Women Ethnic')]
mw2we = mayWeek2we.sum()[1:]
mw2we["week"] = "June Week 2 (7D)"
mw2we["LEV1GRPNAME"] = "Women Ethenic"
mw2we = pd.DataFrame(mw2we).T

start_date = '2024-06-10'
end_date = '2024-06-16'
mayWeek3we = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Women Ethnic')]
mw3we = mayWeek3we.sum()[1:]
mw3we["week"] = "June Week 3 (7D)"
mw3we["LEV1GRPNAME"] = "Women Ethenic"
mw3we = pd.DataFrame(mw3we).T

start_date = '2024-06-17'
end_date = '2024-06-23'
mayWeek4we = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Women Ethnic')]
mw4we = mayWeek4we.sum()[1:]
mw4we["week"] = "June Week 4 (7D)"
mw4we["LEV1GRPNAME"] = "Women Ethenic"
mw4we = pd.DataFrame(mw4we).T

start_date = '2024-06-24'
end_date = '2024-06-30'
mayWeek5we = groupL1nDateDf[(groupL1nDateDf['BILLDATE'] >= start_date) & (groupL1nDateDf['BILLDATE'] <= end_date) & (groupL1nDateDf['LEV1GRPNAME'] == 'Women Ethnic')]
mw5we = mayWeek5we.sum()[1:]
mw5we["week"] = "June Week 5 (7D)"
mw5we["LEV1GRPNAME"] = "Women Ethenic"
mw5we = pd.DataFrame(mw5we).T

mayWbwWL1Dfwe = pd.concat([mw1we,mw2we,mw3we,mw4we,mw5we])
mayWbwWL1Dfwe
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\1903959878.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw1we = mayWeek1we.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\1903959878.py:12: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw2we = mayWeek2we.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\1903959878.py:20: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw3we = mayWeek3we.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\1903959878.py:28: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw4we = mayWeek4we.sum()[1:]
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\1903959878.py:36: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw5we = mayWeek5we.sum()[1:]
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT              week  \
# 0     2.50   3.11   2.49  5.86        0.56    61.74  June Week 1 (2D)
# 0     6.81   8.48   6.79 16.01        1.63   167.08  June Week 2 (7D)
# 0     8.38   9.83   7.63 17.52       74.81   145.90  June Week 3 (7D)
# 0     7.29   8.51   6.42 14.72       87.03   121.14  June Week 4 (7D)
# 0     7.09   8.38   6.25 14.63       84.13   129.19  June Week 5 (7D)
#
#      LEV1GRPNAME
# 0  Women Ethenic
# 0  Women Ethenic
# 0  Women Ethenic
# 0  Women Ethenic
# 0  Women Ethenic

# %%
mayL1Dfwe = mayWbwWL1Dfwe.sum()[:-2]
mayL1Dfwe["LEV1GRPNAME"] = "Women Ethenic"
mayL1Dfwe = pd.DataFrame(mayL1Dfwe).T
mayL1Dfwe
# Out:
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT    LEV1GRPNAME
# 0    32.06  38.31  29.58 68.75      248.15   625.04  Women Ethenic

# %%
groupDateDf = df.groupby(
    by=["BILLDATE"]
).agg({
    "GROSSAMT": "sum",
    "MRPAMT": "sum",
    "NETAMT": "sum",
    "QTY": "sum",
    "DISCOUNTAMT": "sum",
    "PROMOAMT": "sum"
}).reset_index()

# %%
groupDateDf[['GROSSAMT', 'MRPAMT', 'NETAMT']] = groupDateDf[['GROSSAMT', 'MRPAMT', 'NETAMT']]/10000000
groupDateDf[["QTY"]] = groupDateDf[["QTY"]]/10000 
groupDateDf[["DISCOUNTAMT", "PROMOAMT"]] = groupDateDf[["DISCOUNTAMT", "PROMOAMT"]]/100000

# %%
start_date = '2024-06-01'
end_date = '2024-06-02'
mayWeek1 = groupDateDf[(groupDateDf['BILLDATE'] >= start_date) & (groupDateDf['BILLDATE'] <= end_date)]
mayWeek1.sum()
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\1125772984.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mayWeek1.sum()
# GROSSAMT       16.59
# MRPAMT         18.95
# NETAMT         16.54
# QTY            49.90
# DISCOUNTAMT     4.81
# PROMOAMT      236.20
# dtype: float64

# %%
start_date = '2024-06-03'
end_date = '2024-06-09'
mayWeek2 = groupDateDf[(groupDateDf['BILLDATE'] >= start_date) & (groupDateDf['BILLDATE'] <= end_date)]
mayWeek2.sum()
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\2804859170.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mayWeek2.sum()
# GROSSAMT       45.59
# MRPAMT         52.14
# NETAMT         45.45
# QTY           137.78
# DISCOUNTAMT    14.00
# PROMOAMT      655.45
# dtype: float64

# %%
start_date = '2024-06-10'
end_date = '2024-06-16'
mayWeek3 = groupDateDf[(groupDateDf['BILLDATE'] >= start_date) & (groupDateDf['BILLDATE'] <= end_date)]
mayWeek3.sum()
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\2018320698.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mayWeek3.sum()
# GROSSAMT       56.35
# MRPAMT         62.57
# NETAMT         52.15
# QTY           154.74
# DISCOUNTAMT   419.74
# PROMOAMT      622.20
# dtype: float64

# %%
start_date = '2024-06-17'
end_date = '2024-06-23'
mayWeek4 = groupDateDf[(groupDateDf['BILLDATE'] >= start_date) & (groupDateDf['BILLDATE'] <= end_date)]
mayWeek4.sum()
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\2037942897.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mayWeek4.sum()
# GROSSAMT       45.54
# MRPAMT         50.41
# NETAMT         41.11
# QTY           121.36
# DISCOUNTAMT   443.20
# PROMOAMT      486.90
# dtype: float64

# %%
start_date = '2024-06-24'
end_date = '2024-06-30'
mayWeek5 = groupDateDf[(groupDateDf['BILLDATE'] >= start_date) & (groupDateDf['BILLDATE'] <= end_date)]
mayWeek5.sum().T
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\1540937795.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mayWeek5.sum().T
# GROSSAMT       42.74
# MRPAMT         47.54
# NETAMT         38.25
# QTY           110.99
# DISCOUNTAMT   449.59
# PROMOAMT      479.34
# dtype: float64

# %%
mw1 = mayWeek1.sum()
mw1["week"] = "June Week 1 (2D)"
mw1 = pd.DataFrame(mw1).T

mw2 = mayWeek2.sum()
mw2["week"] = "June Week 2 (7D)"
mw2 = pd.DataFrame(mw2).T

mw3 = mayWeek3.sum()
mw3["week"] = "June Week 3 (7D)"
mw3 = pd.DataFrame(mw3).T

mw4 = mayWeek4.sum()
mw4["week"] = "June Week 4 (7D)"
mw4 = pd.DataFrame(mw4).T

mw5 = mayWeek5.sum()
mw5["week"] = "June Week 5 (7D)"
mw5 = pd.DataFrame(mw5).T
# Out:
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\3919735467.py:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw1 = mayWeek1.sum()
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\3919735467.py:5: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw2 = mayWeek2.sum()
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\3919735467.py:9: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw3 = mayWeek3.sum()
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\3919735467.py:13: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw4 = mayWeek4.sum()
# C:\Users\tanmay\AppData\Local\Temp\ipykernel_16908\3919735467.py:17: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mw5 = mayWeek5.sum()

# %%
mayWbwDf = pd.concat([mw1,mw2,mw3,mw4,mw5])
mayWbwDf
# Out:
#   GROSSAMT MRPAMT NETAMT    QTY DISCOUNTAMT PROMOAMT              week
# 0    16.59  18.95  16.54  49.90        4.81   236.20  June Week 1 (2D)
# 0    45.59  52.14  45.45 137.78       14.00   655.45  June Week 2 (7D)
# 0    56.35  62.57  52.15 154.74      419.74   622.20  June Week 3 (7D)
# 0    45.54  50.41  41.11 121.36      443.20   486.90  June Week 4 (7D)
# 0    42.74  47.54  38.25 110.99      449.59   479.34  June Week 5 (7D)

# %%
may = mayWbwDf.sum()[:-1]
may = pd.DataFrame(may).T
may
# Out:
#   GROSSAMT MRPAMT NETAMT    QTY DISCOUNTAMT PROMOAMT
# 0   206.81 231.61 193.49 574.77     1331.35  2480.09

# %%
may.rename(columns={
    "GROSSAMT": "GROSSAMT (Cr)", 
    "MRPAMT": "MRPAMT (Cr)", 
    "NETAMT": "NETAMT (Cr)", 
    "QTY": "QTY (Tth)", 
    "DISCOUNTAMT": "DISCOUNTAMT (lac)", 
    "PROMOAMT": "PROMOAMT (lac)"
}, inplace=True)
may.to_csv(r"June/june.csv")

# %%
mayWbwDf.rename(columns={
    "GROSSAMT": "GROSSAMT (Cr)", 
    "MRPAMT": "MRPAMT (Cr)", 
    "NETAMT": "NETAMT (Cr)", 
    "QTY": "QTY (Tth)", 
    "DISCOUNTAMT": "DISCOUNTAMT (lac)", 
    "PROMOAMT": "PROMOAMT (lac)"
}, inplace=True)
mayWbwDf
# Out:
#   GROSSAMT (Cr) MRPAMT (Cr) NETAMT (Cr) QTY (Tth) DISCOUNTAMT (lac)  \
# 0         16.59       18.95       16.54     49.90              4.81
# 0         45.59       52.14       45.45    137.78             14.00
# 0         56.35       62.57       52.15    154.74            419.74
# 0         45.54       50.41       41.11    121.36            443.20
# 0         42.74       47.54       38.25    110.99            449.59
#
#   PROMOAMT (lac)              week
# 0         236.20  June Week 1 (2D)
# 0         655.45  June Week 2 (7D)
# 0         622.20  June Week 3 (7D)
# 0         486.90  June Week 4 (7D)
# 0         479.34  June Week 5 (7D)

# %%
mayWbwDf.to_csv(r"June/weekByWeek.csv")

# %%
mayWbwWL1Df = pd.concat([juneWbwWL1Dfm,mayWbwWL1Dfb,mayWbwWL1Dfww,mayWbwWL1Dfg,mayWbwWL1Dfi,mayWbwWL1Dfwe])
mayWbwWL1Df
# Out:
#   GROSSAMT MRPAMT NETAMT   QTY DISCOUNTAMT PROMOAMT              week  \
# 0     6.73   7.60   6.71 16.87        2.32    86.86  June Week 1 (2D)
# 0    18.35  20.82  18.28 46.55        6.43   247.32  June Week 2 (7D)
# 0    24.50  26.87  21.70 53.73      280.11   237.38  June Week 3 (7D)
# 0    20.92  22.94  18.03 44.80      289.08   201.78  June Week 4 (7D)
# 0     6.73   7.60   6.71 16.87        2.32    86.86  June Week 5 (7D)
# 0     2.15   2.50   2.14  8.33        0.59    35.09  June Week 1 (2D)
# 0     6.18   7.15   6.16 24.03        1.82    97.73  June Week 2 (7D)
